# %%
import pandas_datareader as pdr
import datetime 
aapl = pdr.get_data_yahoo('AAPL', 
                          start=datetime.datetime(2006, 10, 1), 
                          end=datetime.datetime(2021, 1, 1))

# %%
import numpy as np

# %%
aapl.head()
# Out:
#                 High       Low      Open     Close       Volume  Adj Close
# Date
# 2006-10-02  2.709643  2.653571  2.682143  2.673571  712639200.0   2.306359
# 2006-10-03  2.676786  2.613929  2.658929  2.645714  790708800.0   2.282328
# 2006-10-04  2.695000  2.612857  2.646429  2.692143  829082800.0   2.322379
# 2006-10-05  2.720000  2.647500  2.661786  2.672500  683883200.0   2.305435
# 2006-10-06  2.680000  2.636071  2.657857  2.650714  466958800.0   2.286641

# %%
aapl.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-12-24  133.460007  131.100006  131.320007  131.970001   54930100.0
# 2020-12-28  137.339996  133.509995  133.990005  136.690002  124486200.0
# 2020-12-29  138.789993  134.339996  138.050003  134.869995  121047300.0
# 2020-12-30  135.990005  133.399994  135.580002  133.720001   96452100.0
# 2020-12-31  134.740005  131.720001  134.080002  132.690002   98990400.0
#
#              Adj Close
# Date
# 2020-12-24  131.970001
# 2020-12-28  136.690002
# 2020-12-29  134.869995
# 2020-12-30  133.720001
# 2020-12-31  132.690002

# %%
aapl.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  3588.000000  3588.000000  3588.000000  3588.000000  3.588000e+03
# mean     27.442724    26.866418    27.156185    27.165681  4.217672e+08
# std      25.084472    24.455943    24.771971    24.783755  3.832770e+08
# min       2.642143     2.592857     2.622143     2.615357  2.420510e+07
# 25%       8.799286     8.586875     8.696697     8.684822  1.375946e+08
# 50%      21.231251    20.750536    21.038928    20.957144  2.980684e+08
# 75%      37.155001    36.482499    36.877500    36.952500  5.849795e+08
# max     138.789993   134.339996   138.050003   136.690002  3.372970e+09
#
#          Adj Close
# count  3588.000000
# mean     25.735648
# std      24.947541
# min       2.256140
# 25%       7.491970
# 50%      18.209822
# 75%      35.445166
# max     136.690002

# %%
import pandas as pd
aapl.to_csv('data/aapl_ohlc.csv')
df = pd.read_csv('data/aapl_ohlc.csv', header=0, index_col='Date', parse_dates=True)

# %%
#select first/last ten price of Close COLUMN
df['Close'][:10]
df['Close'][-10:]
# Out:
# Date
# 2020-12-17    128.699997
# 2020-12-18    126.660004
# 2020-12-21    128.229996
# 2020-12-22    131.880005
# 2020-12-23    130.960007
# 2020-12-24    131.970001
# 2020-12-28    136.690002
# 2020-12-29    134.869995
# 2020-12-30    133.720001
# 2020-12-31    132.690002
# Name: Close, dtype: float64

# %%
#locate all item which have 2007
df.loc['2007']
# Out:
#                 High       Low      Open     Close        Volume  Adj Close
# Date
# 2007-01-03  3.092143  2.925000  3.081786  2.992857  1.238320e+09   2.581791
# 2007-01-04  3.069643  2.993572  3.001786  3.059286  8.472604e+08   2.639096
# 2007-01-05  3.078571  3.014286  3.063214  3.037500  8.347416e+08   2.620302
# 2007-01-08  3.090357  3.045714  3.070000  3.052500  7.971068e+08   2.633242
# 2007-01-09  3.320714  3.041071  3.087500  3.306072  3.349298e+09   2.851985
# ...              ...       ...       ...       ...           ...        ...
# 2007-12-24  7.118928  6.956786  6.965357  7.100000  4.802028e+08   6.124821
# 2007-12-26  7.177143  7.029286  7.107500  7.105357  7.037324e+08   6.129442
# 2007-12-27  7.248571  7.064286  7.105357  7.091786  7.955276e+08   6.117734
# 2007-12-28  7.198571  7.031428  7.163929  7.136786  6.996472e+08   6.156554
# 2007-12-31  7.160714  7.062500  7.125000  7.074286  5.393332e+08   6.102638
#
# [251 rows x 6 columns]

# %%
#selecting rows and columns for showing
df.iloc[[1,2,9,12,122],[1,3,5]]
# Out:
#                  Low     Close  Adj Close
# Date
# 2006-10-03  2.613929  2.645714   2.282328
# 2006-10-04  2.612857  2.692143   2.322379
# 2006-10-13  2.669286  2.679286   2.311289
# 2006-10-18  2.639643  2.661786   2.296191
# 2007-03-29  3.293929  3.348214   2.888340

# %%
sample = aapl.sample(20)

# %%
sample
# Out:
#                   High         Low        Open       Close        Volume  \
# Date
# 2009-09-23    6.746428    6.608214    6.621428    6.625000  5.935636e+08
# 2011-03-03   12.849643   12.711429   12.756785   12.841429  5.007884e+08
# 2015-02-23   33.250000   32.415001   32.505001   33.250000  2.838964e+08
# 2020-07-23   97.077499   92.010002   96.997498   92.845001  1.970044e+08
# 2019-10-31   62.292500   59.314999   61.810001   62.189999  1.391620e+08
# 2010-12-22   11.632857   11.555357   11.584286   11.612857  2.659216e+08
# 2020-07-31  106.415001  100.824997  102.885002  106.260002  3.743368e+08
# 2008-08-18    6.350357    6.207857    6.270357    6.263928  5.520144e+08
# 2011-08-04   13.975715   13.476786   13.907500   13.477500  8.714076e+08
# 2011-06-13   11.725357   11.609643   11.685715   11.664286  3.294732e+08
# 2013-10-18   18.187857   18.061071   18.071072   18.174643  2.905420e+08
# 2011-10-06   13.742143   13.278571   13.333215   13.477500  8.125824e+08
# ...

# %%
monthly_data = aapl.resample('M').mean()

# %%
monthly_data
# Out:
#                   High         Low        Open       Close        Volume  \
# Date
# 2006-10-31    2.780942    2.723279    2.750731    2.754497  6.539980e+08
# 2006-11-30    3.078656    3.007245    3.040391    3.048027  6.588040e+08
# 2006-12-31    3.136625    3.051393    3.103964    3.088268  8.445396e+08
# 2007-01-31    3.220214    3.130643    3.180589    3.174339  1.360489e+09
# 2007-02-28    3.095733    3.027951    3.063026    3.061711  7.222292e+08
# ...                ...         ...         ...         ...           ...
# 2020-08-31  118.565596  115.556666  116.969881  117.299762  1.938392e+08
# 2020-09-30  118.036190  112.584762  116.079048  115.125237  1.850365e+08
# 2020-10-31  118.274546  114.911363  116.694090  116.413182  1.315917e+08
# 2020-11-30  118.198999  115.410500  116.748501  116.825999  1.061539e+08
# 2020-12-31  128.608182  125.727726  127.150455  127.290455  1.055832e+08
#
#              Adj Close
# Date
# 2006-10-31    2.376169
# 2006-11-30    2.629384
# ...

# %%
aapl['diff'] = aapl['Open']-aapl['Close']

# %%
aapl
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2006-10-02    2.709643    2.653571    2.682143    2.673571  712639200.0
# 2006-10-03    2.676786    2.613929    2.658929    2.645714  790708800.0
# 2006-10-04    2.695000    2.612857    2.646429    2.692143  829082800.0
# 2006-10-05    2.720000    2.647500    2.661786    2.672500  683883200.0
# 2006-10-06    2.680000    2.636071    2.657857    2.650714  466958800.0
# ...                ...         ...         ...         ...          ...
# 2020-12-24  133.460007  131.100006  131.320007  131.970001   54930100.0
# 2020-12-28  137.339996  133.509995  133.990005  136.690002  124486200.0
# 2020-12-29  138.789993  134.339996  138.050003  134.869995  121047300.0
# 2020-12-30  135.990005  133.399994  135.580002  133.720001   96452100.0
# 2020-12-31  134.740005  131.720001  134.080002  132.690002   98990400.0
#
#              Adj Close      diff
# Date
# 2006-10-02    2.306359  0.008572
# ...

# %%
# Import Matplotlib's `pyplot` module as `plt`
import matplotlib.pyplot as plt

# Plot the closing prices for `aapl`
#aapl['Close'].plot(grid=True)
#aapl['Open'].plot(grid=True)
t = np.arange(2006,2021)
plt.plot(t, aapl['Close'], 'r-', t, aapl['Open'],'b-')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-8cd934801821> in <module>
#       6 #aapl['Open'].plot(grid=True)
#       7 t = np.arange(2006,2021)
# ----> 8 plt.plot(t, aapl['Close'], 'r-', t, aapl['Open'],'b-')
#       9
#      10 # Show the plot
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import date2num , DateFormatter
import datetime as dt

 # different times from the same timespan
TA = list(map(lambda x: date2num(dt.datetime(2015, 6, 15, 12, 1, x)),
         range(1, 20, 5)))
TB =list(map(lambda x: date2num(dt.datetime(2015, 6, 15, 12, 1, x)),
         range(1, 20, 3)))
A = [1.2, 1.1, 0.8, 0.66]
B = [1.3, 1.2, 0.7, 0.5, 0.45, 0.4, 0.3]

fig, ax = plt.subplots()
ax.plot_date(TA, A, 'b--')
ax.plot_date(TB, B, 'g:')
ax.xaxis.set_major_formatter(DateFormatter('%H:%M:%S'))
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import date2num , DateFormatter
import datetime as dt
TA = list(map(lambda x: date2num(dt.datetime(2015, 6, 15, 12, 1, x)),
         range(1, 20, 5)))
TB = list(map(lambda x: date2num(dt.datetime(2015, 6, 15, 12, 1, x)),
         range(1, 20, 3)))

# %%
date_time = aapl['Close']

# %%
aapl

# %%
def westerncandlestick(ax, quotes, width=0.2, colorup='k', colordown='r', 
                 ochl=True, linewidth=0.5):

    """
    Plot the time, open, high, low, close as a vertical line ranging
    from low to high.  Use a rectangular bar to represent the
    open-close span.  If close >= open, use colorup to color the bar,
    otherwise use colordown
    Parameters
    ----------
    ax : `Axes`
        an Axes instance to plot to
    quotes : sequence of quote sequences
        data to plot.  time must be in float date format - see date2num
        (time, open, high, low, close, ...) vs
        (time, open, close, high, low, ...)
        set by `ochl`
    width : float
        fraction of a day for the open and close lines
    colorup : color
        the color of the lines close >= open
    colordown : color
         the color of the lines where close <  open
    ochl: bool
        argument to select between ochl and ohlc ordering of quotes
    linewidth: float
        linewidth of lines
    Returns
    -------
    ret : tuple
        returns (lines, openlines, closelines) where lines is a list of lines
        added
    """

    OFFSET = width / 2.0

    lines = []
    openlines = []
    closelines = []
    for q in quotes:
        if ochl:
            t, open, close, high, low = q[:5]
        else:
            t, open, high, low, close = q[:5]

        if close >= open:
            color = colorup
        else:
            color = colordown

        vline = Line2D( xdata=(t, t), ydata=(low, high),
            color=color, linewidth=linewidth, antialiased=True)
        lines.append(vline)

        openline = Line2D(xdata=(t - OFFSET, t), ydata=(open,open),
                          color=color, linewidth=linewidth, antialiased=True)
        openlines.append(openline)

        closeline = Line2D(xdata=(t , t+OFFSET), ydata=(close,close),
                          color=color, linewidth=linewidth, antialiased=True)
        closelines.append(closeline)

        ax.add_line(vline)
        ax.add_line(openline)
        ax.add_line(closeline)

    ax.autoscale_view()

    return lines, openlines, closelines

# %%
westerncandlestick(plt, aapl, width=0.6, linewidth=1.44, ochl=False)

# %%
import quandl as q
q.ApiConfig.api_key = '88Yx6sJ8EDQzCQZw427L'
d = q.get('BCHAIN/MKPRU')
d['SMA'] = d['Value'].rolling(100).mean()
d.loc['2013-1-1':].plot(title='BTC/USD exchangerate',figsize=(10, 6));

# %%
aapl
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2006-10-02    2.709643    2.653571    2.682143    2.673571  712639200.0
# 2006-10-03    2.676786    2.613929    2.658929    2.645714  790708800.0
# 2006-10-04    2.695000    2.612857    2.646429    2.692143  829082800.0
# 2006-10-05    2.720000    2.647500    2.661786    2.672500  683883200.0
# 2006-10-06    2.680000    2.636071    2.657857    2.650714  466958800.0
# ...                ...         ...         ...         ...          ...
# 2020-12-24  133.460007  131.100006  131.320007  131.970001   54930100.0
# 2020-12-28  137.339996  133.509995  133.990005  136.690002  124486200.0
# 2020-12-29  138.789993  134.339996  138.050003  134.869995  121047300.0
# 2020-12-30  135.990005  133.399994  135.580002  133.720001   96452100.0
# 2020-12-31  134.740005  131.720001  134.080002  132.690002   98990400.0
#
#              Adj Close      diff
# Date
# 2006-10-02    2.306359  0.008572
# ...

# %%
aapl_adj_close = aapl[['Adj Close']]

# %%
daily_change_prc = aapl_adj_close.pct_change()

# %%
daily_change_prc['Adj Close'] = daily_change_prc['Adj Close'].fillna(0)

# %%
daily_change_prc.head()
# Out:
#             Adj Close
# Date
# 2006-10-02   0.000000
# 2006-10-03  -0.010420
# 2006-10-04   0.017549
# 2006-10-05  -0.007296
# 2006-10-06  -0.008152

# %%
bussines_month=aapl.resample('BM').apply(lambda x:x[-1])

# %%
bussines_month.head()
# Out:
#                 High       Low      Open     Close        Volume  Adj Close  \
# Date
# 2006-10-31  2.917143  2.865357  2.908929  2.895714  5.014744e+08   2.497990
# 2006-11-30  3.310000  3.252143  3.293214  3.273571  8.704864e+08   2.823950
# 2006-12-29  3.050000  2.977143  2.998214  3.030000  1.076429e+09   2.613832
# 2007-01-31  3.071429  3.012500  3.030714  3.061786  8.560692e+08   2.641253
# 2007-02-28  3.057143  2.964286  2.964286  3.021786  9.194752e+08   2.606746
#
#                 diff
# Date
# 2006-10-31  0.013214
# 2006-11-30  0.019643
# 2006-12-29 -0.031786
# 2007-01-31 -0.031071
# 2007-02-28 -0.057500

# %%
monthly_changes = bussines_month[['Adj Close']].pct_change()

# %%
monthly_changes['Adj Close'] = monthly_changes['Adj Close'].fillna(0)
monthly_changes.head()
# Out:
#             Adj Close
# Date
# 2006-10-31   0.000000
# 2006-11-30   0.130489
# 2006-12-29  -0.074405
# 2007-01-31   0.010491
# 2007-02-28  -0.013065

# %%
quartals=aapl.resample('4M').apply(lambda x:x[-1])
quartals.head()
# Out:
#                 High       Low      Open     Close        Volume  Adj Close  \
# Date
# 2006-10-31  2.917143  2.865357  2.908929  2.895714  5.014744e+08   2.497990
# 2007-02-28  3.057143  2.964286  2.964286  3.021786  9.194752e+08   2.606746
# 2007-06-30  4.428571  4.324643  4.356071  4.358572  1.137842e+09   3.759926
# 2007-10-31  6.790000  6.605357  6.701071  6.783928  8.333108e+08   5.852162
# 2008-02-29  4.650357  4.457143  4.617500  4.465000  1.255481e+09   3.851738
#
#                 diff
# Date
# 2006-10-31  0.013214
# 2007-02-28 -0.057500
# 2007-06-30 -0.002500
# 2007-10-31 -0.082857
# 2008-02-29  0.152500

# %%
quartal_changes = quartals[['Adj Close']].pct_change()
quartal_changes['Adj Close'] = quartal_changes['Adj Close'].fillna(0)
quartal_changes.head()
# Out:
#             Adj Close
# Date
# 2006-10-31   0.000000
# 2007-02-28   0.043538
# 2007-06-30   0.442383
# 2007-10-31   0.556457
# 2008-02-29  -0.341826

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# Plot the distribution of `daily_pct_c`
monthly_changes.hist(bins=50)

# Show the plot
plt.show()

# Pull up summary statistics
print(monthly_changes.describe())
# Out:
#         Adj Close
# count  171.000000
# mean     0.027732
# std      0.091138
# min     -0.329558
# 25%     -0.021545
# 50%      0.032704
# 75%      0.085088
# max      0.237701

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# Plot the distribution of `daily_pct_c`
quartal_changes.hist(bins=50)

# Show the plot
plt.show()

# Pull up summary statistics
print(quartal_changes.describe())
# Out:
#        Adj Close
# count  44.000000
# mean    0.115335
# std     0.210806
# min    -0.357441
# 25%    -0.001313
# 50%     0.157701
# 75%     0.223069
# max     0.594782

# %%
#The cumulative daily rate of return is useful to determine the value of an investment at regular intervals.
#You can calculate the cumulative daily rate of return by using the daily percentage change values, adding 1 to them and 
#calculating the cumulative product with the resulting values:
cum_monthly_return = (1+monthly_changes).cumprod()

# %%
print(cum_monthly_return)
# Out:
#             Adj Close
# Date
# 2006-10-31   1.000000
# 2006-11-30   1.130489
# 2006-12-29   1.046374
# 2007-01-31   1.057351
# 2007-02-28   1.043538
# ...               ...
# 2020-08-31  51.568563
# 2020-09-30  46.281429
# 2020-10-30  43.503985
# 2020-11-30  47.658321
# 2020-12-31  53.118711
#
# [171 rows x 1 columns]

# %%
# Import matplotlib
import matplotlib.pyplot as plt 

# Plot the cumulative daily returns
cum_monthly_return.plot(figsize=(12,8))

# Show the plot
plt.show()

# %%
cum_quartal_return = (1+quartal_changes).cumprod()
print(cum_quartal_return)
# Out:
#             Adj Close
# Date
# 2006-10-31   1.000000
# 2007-02-28   1.043538
# 2007-06-30   1.505181
# 2007-10-31   2.342748
# 2008-02-29   1.541935
# 2008-06-30   2.065122
# 2008-10-31   1.326962
# 2009-02-28   1.101505
# 2009-06-30   1.756661
# 2009-10-31   2.324865
# 2010-02-28   2.523681
# 2010-06-30   3.102245
# 2010-10-31   3.712138
# 2011-02-28   4.356316
# 2011-06-30   4.139986
# 2011-10-31   4.992354
# 2012-02-29   6.690184
# 2012-06-30   7.202765
# 2012-10-31   7.373901
# 2013-02-28   5.524360
# 2013-06-30   4.995636
# 2013-10-31   6.628657
# 2014-02-28   6.752691
# 2014-06-30   8.393945
# 2014-10-31   9.803669
# 2015-02-28  11.757705
# 2015-06-30  11.528329
# 2015-10-31  11.033017
# 2016-02-29   9.013909
# 2016-06-30   8.966556
# 2016-10-31  10.706880
# 2017-02-28  13.040850
# 2017-06-30  13.766663
# 2017-10-31  16.221742
# 2018-02-28  17.224485
# 2018-06-30  17.969453
# 2018-10-31  21.320228
# 2019-02-28  16.998838
# 2019-06-30  19.505437
# 2019-10-31  24.608971
# ...

# %%
# Import matplotlib
import matplotlib.pyplot as plt 

# Plot the cumulative daily returns
cum_quartal_return.plot(figsize=(12,8))

# Show the plot
plt.show()
